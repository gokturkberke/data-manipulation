# %% [markdown]
# Veri Seti Hikayesi
#
# total_bill:yemegin toplam fiyati(bahsis ve vergi dahil)
#
# tip:bahsis

# %% [markdown]
# sex: ucreti odeyen kisinin cinsiyeti (0=male,1=female)
#
# smoker:grupta sigara icen var mi (0=no,1=yes)
#
# day:gun (3=Thur,4=Fri,5=Sat,6=Sun)
#
# time=ne zaman (0=day,1=night)

# %% [markdown]
# size=Grupta kac kisi var

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
df=tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
#Boxplot
sns.boxplot(x=df["total_bill"]);
#siyah noktalar max degerler
#mavi blok  da medyan %25,50,75. degerler vs

# %%
sns.boxplot(x="day",y="total_bill",data=df);

# %%
#caprazlamalar
#Hangi gunler daha fazla kazaniyoruz?

# %%
#bu tablo da anliyoruz ki pazar gunu daha az musteri olmasina ragmen cumartesiye gore daha fazla para birakilmis

# %%
#Sabah mi aksam mi daha cok kazaniyoruz ?

# %%
sns.boxplot(x="time",y="total_bill",data=df);

# %%
#kisi sayisi kazanc

# %%
sns.boxplot(x="size",y="total_bill",data=df);

# %%
#kisi sayisi ile dogru orantili oldugunu anladik

# %%
sns.boxplot(x="day",y="total_bill",hue="sex",data=df);

# %%
#cumartesi disinda kadinlar erkeklere gore daha az hesap odemis

# %% [markdown]
# Violin Grafigi

# %%
sns.catplot(y="total_bill",kind="violin",data=df);
# Out:
# /Users/gokturkberkekorkut/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Violin Caprazlamalar

# %%
sns.catplot(x="day",y="total_bill",hue="sex",kind="violin",data=df);
# Out:
# /Users/gokturkberkekorkut/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Korelasyon Grafigi

# %%
sns.scatterplot(x="total_bill",y="tip",data=df); #sacilim grafigi

# %%
sns.scatterplot(x="total_bill",y="tip",hue="time",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="time",style="time",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="day",style="time",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",size="size",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="size",size="size",data=df);
